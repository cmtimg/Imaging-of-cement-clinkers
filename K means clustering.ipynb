# %%
# Assume value of k
# iteration - Criteria  lets say 100 iterations
import pandas as pd

# Dataframe
df = pd.read_excel("K_Means.xlsx")
print(df.head())

from sklearn.cluster import KMeans
#apply kmeans
kmeans = KMeans(n_clusters =4, init = "k-means++", max_iter = 300, n_init=10, random_state =0)

model = kmeans.fit(df)
predicted_values = kmeans.predict(df)
from matplotlib import pyplot as plt

plt.scatter(df["X"],df['Y'], c = predicted_values, s= 50, cmap ="viridis")
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s =200, c="black", alpha =0.5)
# Out:
#    X   Y
# 0  1  32
# 1  2  43
# 2  3   1
# 3  4  23
# 4  5  32

# %%
import pandas as pd
import numpy as np

url = filename = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"

headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]

df = pd.read_csv(url,header=None)

df.columns = headers

print(df)

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.  Downloading openpyxl-3.0.7-py2.py3-none-any.whl (243 kB)
# ...
#
# ...

# %%
# Assume value of k
# iteration - Criteria  lets say 100 iterations
import pandas as pd

# Dataframe
df = pd.read_excel("K_Means.xlsx")
print(df.head())

from matplotlib import pyplot as plt

plt.scatter(df["X"],df['Y'],c = predicted_values, s=50, cmap = "viridis")
# Out:
#    X   Y
# 0  1  32
# 1  2  43
# 2  3   1
# 3  4  23
# 4  5  32

# %%
# kmeans for images
#use opencv
# open cv read image as BGR
import cv2 as cv
import numpy as np

im = cv.imread("Image 002.jpg")
img = cv.resize(im,(0,0),im,0.3,0.3)
print(img)
print(img.shape)
print(img.size)
#cv.destroyAllWindows()
cv.imshow("Image", img)
cv.waitKey(90)
# Out:
# [[[130 106 114]
#   [129 105 113]
#   [124 100 108]
#   ...
#   [ 11   3   4]
#   [ 14   6   7]
#   [ 17   9   9]]
#
#  [[146 129 136]
#   [155 137 144]
#   [181 162 170]
#   ...
#   [ 10   3   3]
#   [ 10   2   3]
#   [ 12   4   5]]
#
#  [[214 204 210]
#   [187 177 183]
#   [184 174 180]
#   ...
#   [ 11   3   4]
#   [ 10   3   3]
#   [ 10   3   3]]
#
#  ...
#
#  [[ 60  87  78]
#   [ 67  84  77]
#   [ 68  80  74]
#   ...
#   [ 26  52  66]
#   [ 15  41  55]
#   [ 26  52  66]]
#
#  [[ 56  82  74]
#   [ 75  92  85]
#   [ 63  75  69]
#   ...
#   [ 30  56  70]
#   [ 13  39  53]
#   [ 16  42  56]]
#
#  [[ 61  79  72]
#   [ 66  84  77]
#   [ 73  91  84]
#   ...
#   [ 16  32  48]
#   [ 24  40  56]
#   [ 22  39  55]]]
# (145, 192, 3)
# 83520
# -1

# %%
img2 = img.reshape((-1,3))
#print(img2)
#print(img2.size)
#cv.imshow("img2", img2)
# Reshape
img2 = np.float32(img2)

# %%
cv.destroyAllWindows()
#cv.imshow("Image", img)
cv.waitKey(90)
# Out:
# -1

# %%
# Define criteria = ( type, max_iter = 10 , epsilon = 1.0 )

criteria = (cv.TERM_CRITERIA_EPS + cv.TERM_CRITERIA_MAX_ITER, 20, 1.0)
# Set flags (Just to avoid line break in the code)
flags = cv.KMEANS_RANDOM_CENTERS
# Apply KMeans
#CLUSTERS
k =3
attempts = 20

# For single features
#compactness,labels,centers = cv.kmeans(img2,k,None,criteria,attempts,flags)




ret,label,center=cv.kmeans(img2,k,None,criteria,attempts,cv.KMEANS_RANDOM_CENTERS)
#print(center)
center = np.uint8(center)
#print(center)

res = center[label.flatten()]
res2 = res.reshape(img.shape)
res
cv.imshow("res",res2)

# %%
# Importing the libraries
import cv2 as cv
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd # Importing the dataset 
from sklearn.cluster import KMeans

img = cv.imread("Image 002.jpg")
img2 = img.reshape((-1,3))
float32(img2)



# Using the elbow method to find the optimal number of clusters wcss = [] for i in range(1, 11): 
 wcss.append(kmeans.inertia_)
 kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42) kmeans.fit(X) plt.plot(range(1, 11), wcss) plt.xlabel('Number of clusters') 

y_kmeans = kmeans.fit_predict(X)

plt.ylabel('WCSS') plt.show() # Training the K-Means model on the dataset kmeans = KMeans(n_clusters = 5, init = 'k-means++', random_state = 42) y_kmeans = kmeans.fit_predict(X)

# Visualising the clusters
plt.scatter( X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 60, c = 'blue', label = 'Cluster2')
plt.scatter( X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 60, c = 'red', label = 'Cluster1') plt.scatter( X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 60, c = 'green', label = 'Cluster3') 
plt.scatter( kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 100, c = 'black', label = 'Centroids')
plt.scatter( X[y_kmeans == 3, 0], X[y_kmeans == 3, 1], s = 60, c = 'violet', label = 'Cluster4') plt.scatter( X[y_kmeans == 4, 0], X[y_kmeans == 4, 1], s = 60, c = 'yellow', label = 'Cluster5') plt.xlabel('Annual Income (k$)') plt.ylabel('Spending Score (1-100)') plt.legend() 

plt.show()

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import glob

#img = cv.imread("Image 002.jpg",0)

def fixColor(image):
    return(cv.cvtColor(image,cv.COLOR_BGR2RGB))
           
listdata = glob.glob("./data/*.jpg")
    
for img_name in listdata:
    img  = cv.imread(img_name,0)           

    plt.imshow(fixColor(img))
    plt.show()

    img2 = img.reshape((-1,1))
    img2 = np.float32(img2)

    criteria = (cv.TERM_CRITERIA_EPS + cv.TERM_CRITERIA_MAX_ITER, 30, 1.0)

    flags = cv.KMEANS_RANDOM_CENTERS

    k =5
    attempts = 20
    ret,label,center=cv.kmeans(img2,k,None,criteria,attempts,cv.KMEANS_RANDOM_CENTERS)

    center = np.uint8(center)
           
    res = center[label.flatten()]
    res2 = res.reshape(img.shape)

    plt.imshow(fixColor(res2))
    break

# %%
cv.destroyAllWindows()
cv.waitKey()
# Out:
# -1

# %%
# Elbow method
# Importing the libraries
import cv2 as cv
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd # Importing the dataset 
from sklearn.cluster import KMeans
import sklearn.cluster as cluster

img  = cv.imread("sunil.jpg")
img2 = img.reshape((-1,3))
img2 = np.float32(img2)
df_Short = [img2]


K = range(2,6)
WSS = []
for k in K:
    kmeans = cluster.KMeans(n_clusters = k, init = "k-means++")
    kmeans = kmeans.fit(df_Short)
    wss_iter = kmeans.inertia_
    wss.append(wss_iter)
    
mycenters = pd.DataFrame({"Clusters" : K, "WSS": wss})
print(mycenters)
sns.scatterplot(x = "Clusters" , y = "WSS", data = mycenters, marker = "+")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6760/3778932678.py in <module>
#      18 for k in K:
#      19     kmeans = cluster.KMeans(n_clusters = k, init = "k-means++")
# ---> 20     kmeans = kmeans.fit(df_Short)
#      21     wss_iter = kmeans.inertia_
#      22     wss.append(wss_iter)
#
# e:\python\lib\site-packages\sklearn\cluster\_kmeans.py in fit(self, X, y, sample_weight)
#     977             Fitted estimator.
#     978         """
# --> 979         X = self._validate_data(X, accept_sparse='csr',
#     980                                 dtype=[np.float64, np.float32],
#     981                                 order='C', copy=self.copy_x,
#
# e:\python\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
# ...

# %%
import cv2 as cv
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd # Importing the dataset 

img  = cv.imread("img 002.jpg")           

plt.imshow(fixColor(img))
plt.show()

img2 = img.reshape((-1,3))
img2 = np.float32(img2)

criteria = (cv.TERM_CRITERIA_EPS + cv.TERM_CRITERIA_MAX_ITER, 30, 1.0)

flags = cv.KMEANS_RANDOM_CENTERS

k =3
attempts = 20
ret,label,center=cv.kmeans(img2,k,None,criteria,attempts,cv.KMEANS_RANDOM_CENTERS)

center = np.uint8(center)
           
res = center[label.flatten()]
res2 = res.reshape(img.shape)

plt.imshow(fixColor(res2))
